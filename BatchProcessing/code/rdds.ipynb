# %%
import pyspark
from pyspark.sql import SparkSession
from datetime import datetime
from collections import namedtuple

spark = SparkSession.builder \
    .master("local[*]") \
    .appName('test') \
    .getOrCreate()

# %%
df_green = spark.read.parquet('data/pq/green/*/*')

# %%
rdd = df_green \
    .select('lpep_pickup_datetime', 'PULocationID', 'total_amount') \
    .rdd

# %%
df_green.show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-23 13:10:15
#  lpep_dropoff_datetime | 2020-01-23 13:38:16
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 130
#  passenger_count       | 1
#  trip_distance         | 12.77
#  fare_amount           | 36.0
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 2.05
#  tolls_amount          | 6.12
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 44.97
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 1------------------------------------
#  VendorID              | null
#  lpep_pickup_datetime  | 2020-01-20 15:09:00
#  lpep_dropoff_datetime | 2020-01-20 15:46:00
#  store_and_fwd_flag    | null
#  RatecodeID            | null
#  PULocationID          | 67
#  DOLocationID          | 39
#  passenger_count       | null
#  trip_distance         | 8.0
#  fare_amount           | 29.9
#  extra                 | 2.75
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 33.45
#  payment_type          | null
#  trip_type             | null
#  congestion_surcharge  | null
# -RECORD 2------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-15 20:23:41
#  lpep_dropoff_datetime | 2020-01-15 20:31:18
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 260
#  DOLocationID          | 157
#  passenger_count       | 1
#  trip_distance         | 1.27
#  fare_amount           | 7.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 8.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 3------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-05 16:32:26
#  lpep_dropoff_datetime | 2020-01-05 16:40:51
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 82
#  DOLocationID          | 83
#  passenger_count       | 1
#  trip_distance         | 1.25
#  fare_amount           | 7.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 8.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 4------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-29 19:22:42
#  lpep_dropoff_datetime | 2020-01-29 19:31:02
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 166
#  DOLocationID          | 42
#  passenger_count       | 1
#  trip_distance         | 1.84
#  fare_amount           | 8.0
#  extra                 | 1.0
#  mta_tax               | 0.5
#  tip_amount            | 2.94
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 12.74
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 5------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-15 11:07:42
#  lpep_dropoff_datetime | 2020-01-15 11:11:31
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 179
#  DOLocationID          | 223
#  passenger_count       | 2
#  trip_distance         | 0.76
#  fare_amount           | 5.0
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 5.8
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 6------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-16 08:22:29
#  lpep_dropoff_datetime | 2020-01-16 08:50:24
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 41
#  DOLocationID          | 237
#  passenger_count       | 1
#  trip_distance         | 3.32
#  fare_amount           | 18.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 3.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 25.05
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 2.75
# -RECORD 7------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-28 17:05:28
#  lpep_dropoff_datetime | 2020-01-28 17:26:11
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 75
#  DOLocationID          | 161
#  passenger_count       | 1
#  trip_distance         | 2.21
#  fare_amount           | 14.0
#  extra                 | 1.0
#  mta_tax               | 0.5
#  tip_amount            | 2.78
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 21.33
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 2.75
# -RECORD 8------------------------------------
#  VendorID              | 1
#  lpep_pickup_datetime  | 2020-01-22 14:51:37
#  lpep_dropoff_datetime | 2020-01-22 14:57:29
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 152
#  DOLocationID          | 166
#  passenger_count       | 1
#  trip_distance         | 0.9
#  fare_amount           | 6.0
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 1.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.8
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 9------------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-31 10:25:04
#  lpep_dropoff_datetime | 2020-01-31 10:52:13
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 75
#  DOLocationID          | 234
#  passenger_count       | 1
#  trip_distance         | 6.1
#  fare_amount           | 22.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 26.05
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 2.75
# -RECORD 10-----------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-20 15:50:54
#  lpep_dropoff_datetime | 2020-01-20 16:00:06
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 75
#  DOLocationID          | 41
#  passenger_count       | 1
#  trip_distance         | 1.74
#  fare_amount           | 8.0
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 1.76
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 10.56
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 11-----------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-31 11:35:17
#  lpep_dropoff_datetime | 2020-01-31 11:44:29
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 260
#  DOLocationID          | 226
#  passenger_count       | 5
#  trip_distance         | 1.18
#  fare_amount           | 7.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 8.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 12-----------------------------------
#  VendorID              | 1
#  lpep_pickup_datetime  | 2020-01-04 20:44:28
#  lpep_dropoff_datetime | 2020-01-04 20:52:24
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 129
#  DOLocationID          | 129
#  passenger_count       | 1
#  trip_distance         | 2.2
#  fare_amount           | 9.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 2.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 12.8
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 13-----------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-17 21:47:52
#  lpep_dropoff_datetime | 2020-01-17 22:00:07
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 126
#  passenger_count       | 1
#  trip_distance         | 3.04
#  fare_amount           | 12.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 13.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 14-----------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-21 23:13:47
#  lpep_dropoff_datetime | 2020-01-21 23:17:31
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 61
#  DOLocationID          | 61
#  passenger_count       | 1
#  trip_distance         | 0.85
#  fare_amount           | 5.0
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 6.3
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 15-----------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-02 08:11:21
#  lpep_dropoff_datetime | 2020-01-02 08:32:05
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 66
#  DOLocationID          | 164
#  passenger_count       | 1
#  trip_distance         | 5.06
#  fare_amount           | 18.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 1.5
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 23.55
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 2.75
# -RECORD 16-----------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-27 02:59:20
#  lpep_dropoff_datetime | 2020-01-27 03:05:18
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 7
#  DOLocationID          | 179
#  passenger_count       | 1
#  trip_distance         | 1.57
#  fare_amount           | 6.5
#  extra                 | 0.5
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.8
#  payment_type          | 2
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 17-----------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-16 14:39:13
#  lpep_dropoff_datetime | 2020-01-16 15:19:56
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 74
#  DOLocationID          | 243
#  passenger_count       | 1
#  trip_distance         | 6.8
#  fare_amount           | 29.5
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 30.3
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 18-----------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-16 18:42:24
#  lpep_dropoff_datetime | 2020-01-16 18:47:59
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 66
#  DOLocationID          | 97
#  passenger_count       | 2
#  trip_distance         | 1.06
#  fare_amount           | 6.0
#  extra                 | 1.0
#  mta_tax               | 0.5
#  tip_amount            | 1.56
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 9.36
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# -RECORD 19-----------------------------------
#  VendorID              | 2
#  lpep_pickup_datetime  | 2020-01-03 09:24:54
#  lpep_dropoff_datetime | 2020-01-03 09:33:14
#  store_and_fwd_flag    | N
#  RatecodeID            | 1
#  PULocationID          | 61
#  DOLocationID          | 225
#  passenger_count       | 1
#  trip_distance         | 1.23
#  fare_amount           | 7.0
#  extra                 | 0.0
#  mta_tax               | 0.5
#  tip_amount            | 0.0
#  tolls_amount          | 0.0
#  ehail_fee             | null
#  improvement_surcharge | 0.3
#  total_amount          | 7.8
#  payment_type          | 1
#  trip_type             | 1
#  congestion_surcharge  | 0.0
# only showing top 20 rows

# %%
start = datetime(year=2020, month=1, day=1)

def filter_outliers(row):
    return row.lpep_pickup_datetime >= start

def prepare_for_grouping(row): 
    hour = row.lpep_pickup_datetime.replace(minute=0, second=0, microsecond=0)
    zone = row.PULocationID
    key = (hour, zone)
    
    amount = row.total_amount
    count = 1
    value = (amount, count)

    return (key, value)

def calculate_revenue(left_value, right_value):
    left_amount, left_count = left_value
    right_amount, right_count = right_value
    
    output_amount = left_amount + right_amount
    output_count = left_count + right_count
    
    return (output_amount, output_count)

# %%
RevenueRow = namedtuple('RevenueRow', ['hour', 'zone', 'revenue', 'count'])

# %%
from pyspark.sql import types

def unwrap(row):
    return RevenueRow(
        hour=row[0][0], 
        zone=row[0][1],
        revenue=row[1][0],
        count=row[1][1]
    )

# %%
result_schema = types.StructType([
    types.StructField('hour', types.TimestampType(), True),
    types.StructField('zone', types.IntegerType(), True),
    types.StructField('revenue', types.DoubleType(), True),
    types.StructField('count', types.IntegerType(), True)
])
